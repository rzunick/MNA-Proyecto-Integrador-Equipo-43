# %% [markdown]
# <a href="https://colab.research.google.com/github/rzunick/MNA-Proyecto-Integrador-Equipo-43/blob/main/CIFAR_10_Color_Dataset_Exploration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from zipfile import ZipFile
import os
import shutil
import matplotlib.pyplot as plt

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import  glob

import os
import  numpy as np
import pandas as pd

import logging

# %% [markdown]
# # Dataset V1 - 10 Labels - Gray and Pink

# %%
# URL of the .zip file in the GitHub repository
github_zip_url = "https://github.com/rzunick/MNA-Proyecto-Integrador-Equipo-43/raw/main/cifar_10_color_v1.zip?download="

# Path to save the downloaded .zip file
zip_file_path = '/content/cifar_10_color_v1.zip'

# Download the .zip file from GitHub
response = requests.get(github_zip_url)
with open(zip_file_path, 'wb') as f:
    f.write(response.content)

# Verify the download
if response.status_code == 200:
    print("File downloaded successfully")
else:
    print("Failed to download file")
# Out:
# File downloaded successfully

# %%
# Confirmar tipo de archivo es tipo .zip
# !file /content/cifar_10_color_v1.zip
# Out:
# /content/cifar_10_color_v1.zip: Zip archive data, at least v2.0 to extract, compression method=store

# %%
# Specify the directory where you want to extract the files
extract_to_directory = '/content'

# Create a ZipFile object
with ZipFile(zip_file_path, 'r') as zip_ref:
    # Extract all the contents of the zip file to the specified directory
    zip_ref.extractall(extract_to_directory)

# Dataset Path
path = '/content/cifar_10_color_v1'

# %%
# Configuration 1: 10 labels
labels = ["Red","Yellow","Blue","Orange","Green","Purple","Black","White","Gray","Pink"]

def decode_label(index):
    return  labels[index]

def encode_label_from_path(path):
    for index,value in enumerate(labels):
        if value in path:
            return  index

# %%
# Get image list
image_list = glob.glob(os.path.join(path, '**', '*.*'), recursive=True)
class_list = [encode_label_from_path(item) for item in image_list]

# %%
# Count the number of images per class
from collections import Counter
label_counts = Counter(class_list)
print("Label counts:", label_counts)
# Out:
# Label counts: Counter({8: 5925, 6: 5799, 7: 4838, 0: 4764, 4: 3794, 1: 2946, 3: 2685, 2: 2541, 9: 2007, 5: 682})

# %%
# Convert the counter to a pandas DataFrame
label_df = pd.DataFrame.from_dict(label_counts, orient='index', columns=['count'])
label_df.index = [labels[idx] for idx in label_df.index]

# Plotting the bar chart
plt.figure(figsize=(12, 6))
label_df['count'].plot(kind='bar', color='skyblue')
plt.title('Number of Images per Class')
plt.xlabel('Class Labels')
plt.ylabel('Number of Images')
plt.xticks(rotation=45)
plt.grid(axis='y')

# Display the plot
plt.show()

# %% [markdown]
# # Dataset V2 - 10 Labels - Gray and Brown

# %%
# URL of the .zip file in the GitHub repository
github_zip_url = "https://github.com/rzunick/MNA-Proyecto-Integrador-Equipo-43/raw/main/cifar_10_color_v2.zip?download="

# Path to save the downloaded .zip file
zip_file_path = '/content/cifar_10_color_v2.zip'

# Download the .zip file from GitHub
response = requests.get(github_zip_url)
with open(zip_file_path, 'wb') as f:
    f.write(response.content)

# Verify the download
if response.status_code == 200:
    print("File downloaded successfully")
else:
    print("Failed to download file")

# Confirmar tipo de archivo es tipo .zip
# !file /content/cifar_10_color_v2.zip

# Specify the directory where you want to extract the files
extract_to_directory = '/content/cifar_10_color_v2'

# Create a ZipFile object
with ZipFile(zip_file_path, 'r') as zip_ref:
    # Extract all the contents of the zip file to the specified directory
    zip_ref.extractall(extract_to_directory)

# Dataset Path
path = '/content/cifar_10_color_v2'
# Out:
# File downloaded successfully
# /content/cifar_10_color_v2.zip: Zip archive data, at least v2.0 to extract, compression method=store

# %%
# Configuration 2: 10 labels
labels = ["Red","Yellow","Blue","Orange","Green","Purple","Black","White","Gray","Brown"]

def decode_label(index):
    return  labels[index]

def encode_label_from_path(path):
    for index,value in enumerate(labels):
        if value in path:
            return  index

# %%
# Get image list
image_list = glob.glob(os.path.join(path, '**', '*.*'), recursive=True)
class_list = [encode_label_from_path(item) for item in image_list]

# Count the number of images per class
from collections import Counter
label_counts = Counter(class_list)
print("Label counts:", label_counts)
# Out:
# Label counts: Counter({9: 14957, 6: 9152, 8: 8371, 0: 4423, 7: 3976, 2: 2429, 4: 2413, 1: 2020, 3: 1585, 5: 674})

# %%
# Convert the counter to a pandas DataFrame
label_df = pd.DataFrame.from_dict(label_counts, orient='index', columns=['count'])
label_df.index = [labels[idx] for idx in label_df.index]

# Plotting the bar chart
plt.figure(figsize=(12, 6))
label_df['count'].plot(kind='bar', color='skyblue')
plt.title('Number of Images per Class')
plt.xlabel('Class Labels')
plt.ylabel('Number of Images')
plt.xticks(rotation=45)
plt.grid(axis='y')

# Display the plot
plt.show()

# %% [markdown]
# # Dataset V3 - 8 Labels - Primary and Secondary Colors

# %%
# URL of the .zip file in the GitHub repository
github_zip_url = "https://github.com/rzunick/MNA-Proyecto-Integrador-Equipo-43/raw/main/cifar_10_color_v3.zip?download="

# Path to save the downloaded .zip file
zip_file_path = '/content/cifar_10_color_v3.zip'

# Download the .zip file from GitHub
response = requests.get(github_zip_url)
with open(zip_file_path, 'wb') as f:
    f.write(response.content)

# Verify the download
if response.status_code == 200:
    print("File downloaded successfully")
else:
    print("Failed to download file")

# Confirmar tipo de archivo es tipo .zip
# !file /content/cifar_10_color_v3.zip

# Specify the directory where you want to extract the files
extract_to_directory = '/content/cifar_10_color_v3'

# Create a ZipFile object
with ZipFile(zip_file_path, 'r') as zip_ref:
    # Extract all the contents of the zip file to the specified directory
    zip_ref.extractall(extract_to_directory)

# Dataset Path
path = '/content/cifar_10_color_v3'
# Out:
# File downloaded successfully
# /content/cifar_10_color_v3.zip: Zip archive data, at least v2.0 to extract, compression method=store

# %%
# Configuration 3: 8 labels
labels = ["Red","Yellow","Blue","Orange","Green","Purple","Black","White"]

def decode_label(index):
    return  labels[index]

def encode_label_from_path(path):
    for index,value in enumerate(labels):
        if value in path:
            return  index

# %%
# Get image list
image_list = glob.glob(os.path.join(path, '**', '*.*'), recursive=True)
class_list = [encode_label_from_path(item) for item in image_list]

# Count the number of images per class
from collections import Counter
label_counts = Counter(class_list)
print("Label counts:", label_counts)
# Out:
# Label counts: Counter({6: 21088, 7: 8733, 0: 5519, 4: 4577, 1: 3369, 3: 2972, 2: 2851, 5: 891})

# %%
# Convert the counter to a pandas DataFrame
label_df = pd.DataFrame.from_dict(label_counts, orient='index', columns=['count'])
label_df.index = [labels[idx] for idx in label_df.index]

# Plotting the bar chart
plt.figure(figsize=(12, 6))
label_df['count'].plot(kind='bar', color='skyblue')
plt.title('Number of Images per Class')
plt.xlabel('Class Labels')
plt.ylabel('Number of Images')
plt.xticks(rotation=45)
plt.grid(axis='y')

# Display the plot
plt.show()

# %% [markdown]
# # Dataset V4 - 8 Labels - Primary and Secondary Modified Purple/Brown

# %%
# URL of the .zip file in the GitHub repository
github_zip_url = "https://github.com/rzunick/MNA-Proyecto-Integrador-Equipo-43/raw/main/cifar_10_color_v4.zip?download="

# Path to save the downloaded .zip file
zip_file_path = '/content/cifar_10_color_v4.zip'

# Download the .zip file from GitHub
response = requests.get(github_zip_url)
with open(zip_file_path, 'wb') as f:
    f.write(response.content)

# Verify the download
if response.status_code == 200:
    print("File downloaded successfully")
else:
    print("Failed to download file")

# Confirmar tipo de archivo es tipo .zip
# !file /content/cifar_10_color_v4.zip

# Specify the directory where you want to extract the files
extract_to_directory = '/content/cifar_10_color_v4'

# Create a ZipFile object
with ZipFile(zip_file_path, 'r') as zip_ref:
    # Extract all the contents of the zip file to the specified directory
    zip_ref.extractall(extract_to_directory)

# Dataset Path
path = '/content/cifar_10_color_v4'
# Out:
# File downloaded successfully
# /content/cifar_10_color_v4.zip: Zip archive data, at least v2.0 to extract, compression method=store

# %%
# Configuration 4: 8 labels
labels = ["Red","Yellow","Blue","Orange","Green","Brown","Black","White"]

def decode_label(index):
    return  labels[index]

def encode_label_from_path(path):
    for index,value in enumerate(labels):
        if value in path:
            return  index

# %%
# Get image list
image_list = glob.glob(os.path.join(path, '**', '*.*'), recursive=True)
class_list = [encode_label_from_path(item) for item in image_list]

# Count the number of images per class
from collections import Counter
label_counts = Counter(class_list)
print("Label counts:", label_counts)
# Out:
# Label counts: Counter({5: 16931, 6: 12942, 7: 6306, 0: 4649, 2: 2803, 4: 2613, 1: 2123, 3: 1633})

# %%
# Convert the counter to a pandas DataFrame
label_df = pd.DataFrame.from_dict(label_counts, orient='index', columns=['count'])
label_df.index = [labels[idx] for idx in label_df.index]

# Plotting the bar chart
plt.figure(figsize=(12, 6))
label_df['count'].plot(kind='bar', color='skyblue')
plt.title('Number of Images per Class')
plt.xlabel('Class Labels')
plt.ylabel('Number of Images')
plt.xticks(rotation=45)
plt.grid(axis='y')

# Display the plot
plt.show()
